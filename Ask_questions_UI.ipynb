# %% [markdown]
# ## Ask questions

# %% [markdown]
# 1. Prerequisites
#     - Just ask directly:
#         - “What are the prerequisites for 6.824?”
#         - “Can I take 6.046 without 6.006?”
# 2. Course planning
#     - “Plan my next semester with 4 courses focused on AI”
#     - “Suggest courses for systems + machine learning track”
# 3. Personalized (use sidebar history)
#     - First fill sidebar: Completed 6.1200 with A, 6.1010 with B+
#     - Then ask:
#         - “What courses can I take next in computer systems?”
#         - “Am I ready for 6.824?”
# 4. Compare courses
#     - “6.824 vs 6.858 — which should I take?”
#     - “Difference between 6.006 and 6.046?”
# 5. Clarification-based queries
#     -  courses require 6.006?”
#     - “List advanced AI courses with prerequisites”

# %% [markdown]
# - If questions are structured in this way, better answers will be obtained:
#     - Good: “Based on my completed courses (6.1200, 6.1010), suggest 3 next courses in systems.”
#     - Better: “Using MIT catalog prerequisites, suggest 3 system courses I’m eligible for given I completed 6.1200 (A) and 6.1010 (B+).”
